# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
f = "/content/drive/MyDrive/Colab Notebooks/Ventas Mensuales Fanta 33cl.csv"
dataset_fantam = open(f, "r")

# %%
import pandas as pd
fm = pd.read_csv(dataset_fantam, sep=';')

# %%
pip install pmdarima
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.9 MB/s eta 0:00:00
# ...

# %%
import pmdarima as pm

import pandas as pd

# %%
arimafm = pm.auto_arima(fm["Unidades"], m=12)

# %%
arimafm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  SARIMAX Results
# ...
# Dep. Variable:                          y   No. Observations:                   54
# Model:             SARIMAX(0, 1, [1], 12)   Log Likelihood                -276.544
# Date:                    Sat, 29 Jul 2023   AIC                            559.088
# Time:                            13:23:15   BIC                            564.301
# Sample:                                 0   HQIC                           560.999
#                                      - 54
# Covariance Type:                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -39.4224     17.410     -2.264      0.024     -73.546      -5.299
# ma.S.L12      -0.6584      0.431     -1.526      0.127      -1.504       0.187
# ...

# %%
arimafm.plot_diagnostics()

# %%
from matplotlib import pyplot

pyplot.plot(fm["Unidades"])

pyplot.plot(arimafm.predict(12))

print(arimafm.predict(12))
# Out:
# 54    1612.854196
# 55    1584.236421
# 56    1026.649838
# 57    1034.959283
# 58     745.535457
# 59    1228.200951
# 60     781.715067
# 61     722.452611
# 62     952.680123
# 63    1035.431329
# 64    1111.992446
# 65    1142.291413
# dtype: float64
